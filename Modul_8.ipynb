# %%
import matplotlib.pyplot as plt
from skimage import data
from skimage.transform import swirl

image = data.checkerboard()
swirled = swirl(image, rotation=0, strength=10, radius=120)

fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, figsize=(8, 3), sharex=True, sharey=True)

ax0.imshow(image, cmap=plt.cm.gray)
ax0.axis('off')
ax1.imshow(swirled, cmap=plt.cm.gray)
ax1.axis('off')

plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

image = cv.imread("Panji Satrio.jpeg")

h, w = image.shape[:2]

half_height, half_width = h//4, w//8
transition_matrix = np.float32([[1, 0, half_width], [0, 1, half_height]])
img_transition = cv.warpAffine(image, transition_matrix, (w, h))

plt.imshow(cv.cvtColor(img_transition, cv.COLOR_BGR2RGB))
plt.title("Translation")
plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

image = cv.imread("Panji Satrio.jpeg")

h, w = image.shape[:2]

rotation_matrix = cv.getRotationMatrix2D((w/2,h/2), -180, 0.5)
rotated_image = cv.warpAffine(image,
rotation_matrix, (w, h))

plt.imshow(cv.cvtColor(rotated_image, cv.COLOR_BGR2RGB))
plt.title("Rotation")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import measure

regions = np.zeros((8,8), dtype=bool)
regions[:3,:3] = 1
regions[6:,6:] = 1

labeled = measure.label(regions)
plt.imshow(labeled, interpolation='nearest')
plt.show()

# %%
structuring_element = np.ones((3,3), dtype=bool)
labeled = measure.label(regions, connectivity=structuring_element)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-585e9c5f9dd4> in <cell line: 2>()
#       1 structuring_element = np.ones((3,3), dtype=bool)
# ----> 2 labeled = measure.label(regions, connectivity=structuring_element)
#
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py in fixed_func(*args, **kwargs)
#     280
#     281             # Call the function with the fixed arguments
# --> 282             return func(*args, **kwargs)
#     283
#     284         if func.__doc__ is not None:
#
# /usr/local/lib/python3.10/dist-packages/skimage/measure/_label.py in label(label_image, background, return_num, connectivity)
#     119     """
#     120     if label_image.dtype == bool:
# --> 121         return _label_bool(label_image, background=background,
#     122                            return_num=return_num, connectivity=connectivity)
#     123     else:
#
# /usr/local/lib/python3.10/dist-packages/skimage/measure/_label.py in _label_bool(image, background, return_num, connectivity)
#      16         connectivity = image.ndim
#      17
# ---> 18     if not 1 <= connectivity <= image.ndim:
#      19         raise ValueError(
#      20             f'Connectivity for {image.ndim}D image should '
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
properties = measure.regionprops(labeled)
sizes = [prop.area for prop in properties]

print('Background size:', sizes[0])
print('Size of first region:', sizes[1])
# Out:
# Background size: 9
# Size of first region: 4

# %%
array = np.random.random_sample(regions.shape)
sums = measure.regionprops(labeled, intensity_image=array)

print('Sum of first region:', sums[0].intensity_image.sum())
# Out:
# Sum of first region: 5.232739367449968

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
image = cv.imread("Panji Satrio.jpeg")
fig, ax = plt.subplots(1, 3, figsize=(16, 8))

# image size being 0.15 times of it's original size
image_scaled = cv.resize(image, None, fx=0.15, fy=0.15)
ax[0].imshow(cv.cvtColor(image_scaled, cv.COLOR_BGR2RGB))
ax[0].set_title("Linear Interpolation Scale")

# image size being 2 times of it's original size
image_scaled_2 = cv.resize(image, None, fx=2, fy=2, interpolation=cv.INTER_CUBIC)
ax[1].imshow(cv.cvtColor(image_scaled_2, cv.COLOR_BGR2RGB))
ax[1].set_title("Cubic Interpolation Scale")

# image size being 0.15 times of it's original size
image_scaled_3 = cv.resize(image, (200, 400), interpolation=cv.INTER_AREA)
ax[2].imshow(cv.cvtColor(image_scaled_3, cv.COLOR_BGR2RGB))
ax[2].set_title("Skewed Interpolation Scale")
# Out:
# Text(0.5, 1.0, 'Skewed Interpolation Scale')
